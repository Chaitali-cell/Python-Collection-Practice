# %%
# print string  
s1 = '''pune is a 
clean city''' # more than one line use triple quotation
s1
# Out:
# 'pune is a \nclean city'

# %%
print(type('hello')) #print type of collection
# Out:
# <class 'str'>

# %%
a = 'hello' #print last item in the string
a[-1]
# Out:
# 'o'

# %%
a[2] #print item using index function
# Out:
# 'l'

# %%
a[-2]
# Out:
# 'l'

# %%
a[2] = 0 #string does not support assignment operator
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 a[2] = 0
#
# TypeError: 'str' object does not support item assignment

# %%
del a[2] #string does not support deletion
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 del a[2]
#
# TypeError: 'str' object doesn't support item deletion

# %%
"HELLO".lower() #print lower case
# Out:
# 'hello'

# %%
"hello".upper() #print upper case
# Out:
# 'HELLO'

# %%
"Hello world".title() #first letter is capital of each word
# Out:
# 'Hello World'

# %%
"hello".capitalize() #print first letter capital
# Out:
# 'Hello'

# %%
" hi ".strip() #remove spacing
# Out:
# 'hi'

# %%
" hi".lstrip() #remove left side spacing
# Out:
# 'hi'

# %%
"hi ".rstrip() #remove right side spacing
# Out:
# 'hi'

# %%
"apple".replace("p","b") #replace letter
# Out:
# 'abble'

# %%
"a,b,c".split(",") #split the string
# Out:
# ['a', 'b', 'c']

# %%
"-".join(['a','b','c']) #join string using hypen
# Out:
# 'a-b-c'

# %%
"hello".find("e") #find number of times letter is present in string
# Out:
# 1

# %%
"hello".index("l") #find index position using item
# Out:
# 2

# %%
"banana".count("a") #count number of times item repeated
# Out:
# 3

# %%
"hello".startswith("he") #check item is start with the given value in the string
# Out:
# True

# %%
"hello".startswith("te")
# Out:
# False

# %%
"hello".endswith("lo") #check string end with given item
# Out:
# True

# %%
"hello".endswith("ot")
# Out:
# False

# %%
"abc".isalpha() #check string is in alphabet
# Out:
# True

# %%
"123".isdigit() #check string is in integer
# Out:
# True

# %%
"abc123".isalnum() #check string is in alpha-numberic
# Out:
# True

# %%
len("pune") #find the length of string
# Out:
# 4

# %%
#sort the string in alphabetical order
sorted("pune")
# Out:
# ['e', 'n', 'p', 'u']

# %%
list("hello") #print list using string
# Out:
# ['h', 'e', 'l', 'l', 'o']

# %%
" ".join(sorted("pune")) # join the string
# Out:
# 'e n p u'

# %%
"".join(sorted("pune123")) #join the string using ascii value
# Out:
# '123enpu'

# %%
len("123") #find the length of numeric string
# Out:
# 3
