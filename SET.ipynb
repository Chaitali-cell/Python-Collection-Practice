# %%
s1 = {} #curly braceses does not identify set properly
print(type(s1))
# Out:
# <class 'dict'>

# %%
s2 = set() #this method use to define class set
print(type(s2))
# Out:
# <class 'set'>

# %%
#print set using curly braceses
s3 = {1,2,2,3,4,5,6,4,6,7} #set does not repeat values
s3
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
#update set using add method
s3.add(20)
s3 #add the value at last position
# Out:
# {1, 2, 3, 4, 5, 6, 7, 20}

# %%
#update the string 
s3.update("abc")
s3 #string is iterable
# Out:
# {1, 2, 20, 3, 4, 5, 6, 7, 'a', 'b', 'c'}

# %%
s3.update(20)
s3 #integer is not iterable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 s3.update(20)
#       2 s3
#
# TypeError: 'int' object is not iterable

# %%
s3.add(100)
s3
# Out:
# {'0', 1, 100, 2, '2', 20, 3, 4, 5, 6, 7, 'a', 'b', 'c'}

# %%
s3.add("pune")
s3
# Out:
# {'0', 1, 100, 2, '2', 20, 3, 4, 5, 6, 7, 'a', 'b', 'c', 'pune'}

# %%
# use remove function
s3.remove("pune")
s3
# Out:
# {'0', 1, 100, 2, '2', 20, 3, 4, 5, 6, 7, 'a', 'b', 'c'}

# %%
s3.remove(100) # remove value
s3
# Out:
# {'0', 1, 2, '2', 20, 3, 4, 5, 6, 7, 'a', 'b', 'c'}

# %%
#discard the alphabet a
s3.discard('a')
s3
# Out:
# {'0', 1, 2, '2', 20, 3, 4, 5, 6, 7, 'b', 'c'}

# %%
print(s3.discard)
# Out:
# <built-in method discard of set object at 0x000002BD79007E60>

# %%
#print set using different data types
s4 = {3,"ram",78.86}
s4
# Out:
# {3, 78.86, 'ram'}

# %%
A = {1,2,3,4,5}
B = {4,5,6,7,8}
A.intersection(B)
# Out:
# {4, 5}

# %%
A.union(B)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
A.difference(B)
# Out:
# {1, 2, 3}

# %%
B.difference(A)
# Out:
# {6, 7, 8}

# %%
(A.difference(B)).union(B.difference(A))
# Out:
# {1, 2, 3, 6, 7, 8}

# %%
s = {1, 2, 3}
s.clear()
print(s)
# Out:
# set()

# %%
s1 = {1, 2, 3}
s2 = s1.copy()

print(s2)
# Out:
# {1, 2, 3}

# %%
a = {1, 2, 3}
b = {3, 4, 5}

print(a.union(b))
# Out:
# {1, 2, 3, 4, 5}

# %%
a = {1, 2, 3}
b = {2, 3, 4}

print(a.intersection(b))
# Out:
# {2, 3}

# %%
a = {1, 2, 3}
b = {2, 3, 4}

print(a.difference(b))
# Out:
# {1}

# %%
a = {1, 2, 3}
b = {2, 3, 4}

print(a.symmetric_difference(b))
# Out:
# {1, 4}

# %%
a = {1, 2, 3, 4}
b = {1, 2}

print(a.issuperset(b))
# Out:
# True

# %%
a = {1, 2}
b = {3, 4}

print(a.isdisjoint(b))
# Out:
# True
